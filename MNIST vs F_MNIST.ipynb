# %%
# 16.1 (IMAGE RECOGNITION: THE FASHION-MNIST DATASET)

# %%
# !pip install tensorflow

# %%
from tensorflow.keras.datasets import mnist

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

import seaborn as sns

sns.set(font_scale=2)

# %%
from tensorflow.keras.models import Sequential
cnn = Sequential()

# %%
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D

# %%
cnn.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)))

# %%
cnn.add(MaxPooling2D(pool_size=(2, 2)))

# %%
cnn.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2, 2)))

# %%
cnn.add(Flatten())

# %%
cnn.add(Dense(units=4096, activation='relu'))

# %%
cnn.add(Dense(units=128, activation='relu'))

# %%
cnn.add(Dense(units=10, activation='softmax'))

# %%
cnn.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# %%
predictions = cnn.predict(X_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step

# %%
 def display_probabilities(prediction):
          for index, probability in enumerate(prediction):
              print(f'{index}: {probability:.10%}')

# %%
display_probabilities(predictions[495])
# Out:
# 0: 0.0000000022%
# 1: 0.0000000000%
# 2: 0.0118589691%
# 3: 0.0000000208%
# 4: 0.0000055876%
# 5: 0.0000000000%
# 6: 0.0000000000%
# 7: 0.0000000778%
# 8: 0.0000000000%
# 9: 99.9881386757%

# %%
import numpy as np
index = np.random.choice(np.arange(len(X_train)), 24, replace=False)
figure, axes = plt.subplots(nrows=4, ncols=6, figsize=(16, 9))
for item in zip(axes.ravel(), X_train[index], y_train[index]):
    axes, image, target = item
    axes.imshow(image, cmap=plt.cm.gray_r)
    axes.set_xticks([])  # remove x-axis tick marks
    axes.set_yticks([])  # remove y-axis tick marks
    axes.set_title(target)
    plt.tight_layout()

# %%
from tensorflow.keras.datasets import fashion_mnist

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

import seaborn as sns

sns.set(font_scale=2)

# %%
import numpy as np
index = np.random.choice(np.arange(len(X_train)), 24, replace=False)
figure, axes = plt.subplots(nrows=4, ncols=6, figsize=(16, 9))
for item in zip(axes.ravel(), X_train[index], y_train[index]):
    axes, image, target = item
    axes.imshow(image, cmap=plt.cm.gray_r)
    axes.set_xticks([])  # remove x-axis tick marks
    axes.set_yticks([])  # remove y-axis tick marks
    axes.set_title(target)
    plt.tight_layout()

# %%
##################################################################QUESTIONS############################################################################

# %%
# 16.1 (IMAGE RECOGNITION: THE FASHION-MNIST DATASET) 
# 1.) How well does the model perform on Fashion-MNIST compared to MNIST?
# Fashion-MNIST and MNIST both perform well.

# 2.) How do the training times compare?
# They both had a training time of around 18 seconds. There wasnt really a difference.

# %%
# 16.4 (CONVNET LAYERS: THE MNIST DATASET)
# When Dense layer is removed. How does this change the prediction accuracy and speed? 
# When the dense layer is removed, the speed is 3s 9ms/step, and the prediction tells me that class 9 is the most accurate compared to the model.
# When Dense layer is add with 4096. How does this change the prediction accuracy and speed? 
# When the dense layer is add with 4096, the speed is 6s 19ms/step, and the prediction tells me that class 9 is the most accurate compared to the model.
