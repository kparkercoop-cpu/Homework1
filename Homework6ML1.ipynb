# %%
# %matplotlib inline

# %%
import nltk

nltk.download('stopwords')

nltk.download('wordnet')

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\matco\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\matco\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\matco\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# !pip install requests

import requests

target_url = "https://www.gutenberg.org/files/2265/2265-0.txt"

response = requests.get(target_url)
data = response.text
# Out:
# Requirement already satisfied: requests in c:\users\matco\anaconda3\lib\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\matco\anaconda3\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\matco\anaconda3\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\matco\anaconda3\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\matco\anaconda3\lib\site-packages (from requests) (2026.2.25)

# %%
from textblob import TextBlob
data = response.text

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# %%
items = blob.word_counts.items()

# %%
items = [item for item in items if item[0] not in stop_words]

# %%
from operator import itemgetter
sorted_items = sorted(items, key=itemgetter(1), reverse=True)

# %%
top20 = sorted_items[1:21]

# %%
import pandas as pd
df = pd.DataFrame(top20, columns=['word', 'count'])
df
# Out:
#       word  count
# 0     lord    211
# 1     haue    175
# 2     king    173
# 3    shall    107
# 4     come    106
# 5     thou    105
# 6      let    104
# 7   hamlet    100
# 8     good     98
# 9      hor     95
# 10     thy     90
# 11   enter     85
# 12      oh     81
# 13    like     78
# 14    well     70
# 15     may     69
# 16    know     69
# 17   selfe     68
# 18   would     68
# 19    loue     65

# %%
import matplotlib.pyplot as plt
plt.gcf().tight_layout()
axes = df.plot.bar(x='word', y='count', legend=False)

# %%
conda install -c conda-forge wordcloud
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from nltk.corpus import stopwords
from string import punctuation

stop_words = stopwords.words('english')

words = [
    word.lemmatize().lower()
    for word in blob.words
    if word.lower() not in stop_words
    and word.lower() not in punctuation
    and word.isalpha()
]

# %%
from collections import Counter

word_counts = Counter(words)

# %%
import imageio

image_file="https://media.cheggcdn.com/media/216/21621ee5-e80f-47f3-9145-513f2229b390/phploeBuh.png"

mask_image =imageio.v3.imread(image_file)

# %%
# !pip install wordcloud

from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(
    width=1000,
    height=1000,
    background_color='black',
    mask=mask_image
).generate_from_frequencies(word_counts)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# Requirement already satisfied: wordcloud in c:\users\matco\anaconda3\lib\site-packages (1.9.6)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\matco\anaconda3\lib\site-packages (from wordcloud) (2.3.5)
# Requirement already satisfied: pillow in c:\users\matco\anaconda3\lib\site-packages (from wordcloud) (12.0.0)
# Requirement already satisfied: matplotlib in c:\users\matco\anaconda3\lib\site-packages (from wordcloud) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\matco\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\matco\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\matco\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\matco\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\matco\anaconda3\lib\site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\matco\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\matco\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\matco\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
